# %% [markdown]
# <a href="https://colab.research.google.com/github/sg1774/git_test2/blob/master/1%EC%B0%A8%EC%8B%9C_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
print("asdf")
a = int(input("input 1 "))
b = int(input("input 2 "))
print(a+b)
# Out:
# hello world
# asdf
# input 1 3
# input 2 5
# 8

# %% [markdown]
# #짠
# ##두둥등장
# ```
# #include <bits/stdc++.h>
# using namespace std;
# int main()
# {
#   int a,b;
#   scanf("%d %d", &a, &b);
#   printf("%d", a+b);
#   return 0;
# }
# ```
# 정수 두 개의 합을 출력하는 코드
#
# <img src="https://post-phinf.pstatic.net/MjAxOTEwMDJfMTg3/MDAxNTY5OTk0NDgzNzQ5.e7KQf8juePJRkbG7swr3pFBdXkD5wd2_6edImNkYxqgg.Opxv5U9EpcnJMLx99DLp9Pa6p8qpaa-v3GzQlGCCvSMg.JPEG/zzz-min.jpeg?type=w1200"/>

# %%
pip install requests

# %%
import requests

# %%
res = requests.get("https://api.covid19api.com/summary")
res.status_code
# res.headers
raw_data = res.json()

# %%
raw_data
# Out:
# {'Countries': [{'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Date': '2020-08-08T00:37:57Z',
#    'NewConfirmed': 67,
#    'NewDeaths': 4,
#    'NewRecovered': 98,
#    'Premium': {},
#    'Slug': 'afghanistan',
#    'TotalConfirmed': 36896,
#    'TotalDeaths': 1298,
#    'TotalRecovered': 25840},
#   {'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Date': '2020-08-08T00:37:57Z',
#    'NewConfirmed': 127,
#    'NewDeaths': 6,
#    'NewRecovered': 32,
#    'Premium': {},
#    'Slug': 'albania',
#    'TotalConfirmed': 6016,
#    'TotalDeaths': 188,
#    'TotalRecovered': 3155},
#   {'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Date': '2020-08-08T00:37:57Z',
#    'NewConfirmed': 571,
#    'NewDeaths': 12,
#    'NewRecovered': 436,
#    'Premium': {},
#    'Slug': 'algeria',
#    'TotalConfirmed': 33626,
#    'TotalDeaths': 1273,
#    'TotalRecovered': 23238},
#   {'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Date': '2020-08-08T00:37:57Z',
# ...

# %%
# raw_data['Countries']
with open("asdf.txt", 'w') as f:
  for i in raw_data['Countries']:
    text = i['Country'] + "\t" + str(i['NewConfirmed']) + "\n"
    f.write(text)
    f.close
